# %% [markdown]
# <a href="https://colab.research.google.com/github/tonytani37/opendata/blob/main/geopandas%E3%82%92%E4%BD%BF%E3%81%A3%E3%81%A6geo%E3%83%87%E3%83%BC%E3%82%BF%E3%82%92%E6%89%B1%E3%81%86%E3%81%93%E3%81%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geodatasets

# %%
import geopandas as gpd

# gdfs = gpd.read_file("/content/A26-10_34-g_SedimentDisasterHazardArea_Surface.shp")
# gdf = gpd.read_file("/content/A26-10_34-g_SedimentDisasterHazardArea_Line.shp")
gdf = gpd.read_file("/content/japan_ver84.shp")


# gdfs.tail()

# %%
gdf

# %%
gdf = gdf[gdf['SIKUCHOSON'] == '廿日市市']  #gdfデータ(地図デーア）から廿日市市を抜いている

# %%
gdf.plot(color='lightgray',figsize=(10,10))
# Out:
# <Axes: >
